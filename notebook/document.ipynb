# %% [markdown]
# ### Data ingestion

# %%
# document structure

from langchain_core.documents import Document

# %%
document = Document(
    page_content="This is a sample document.",
    metadata={
      "source": "sample_source",
      "page": 1, 
      "date": "2023-01-01", 
      "author": "John Doe"
    }
)
document
# Out:
# Document(metadata={'source': 'sample_source', 'page': 1, 'date': '2023-01-01', 'author': 'John Doe'}, page_content='This is a sample document.')

# %%
# create a simple txt file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
  "../data/text_files/python_intro.txt" : """Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",

"../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems."""

}

for filepath, content in sample_texts.items():
  with open(filepath, 'w', encoding="utf-8") as f:
    f.write(content)
print("✔️ Sample text files created!")
# Out:
# ✔️ Sample text files created!

# %% [markdown]
# #### now how to read these files

# %%
# TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
doc = loader.load()
print(doc)
# Out:
# C:\Users\jatin\AppData\Local\Temp\ipykernel_19632\125633640.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# directory loader 
from langchain_community.document_loaders import DirectoryLoader

# load all the text files from the directory
dir_loader = DirectoryLoader(
  "../data/text_files", 
  glob= "**/*.txt",  # Pattern to match files
  loader_cls = TextLoader,
  loader_kwargs = {'encoding': 'utf-8'}
)
documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems.'),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# dirctory loader for pdfs
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import PyMuPDFLoader

dir_loader = DirectoryLoader(
  "../data/pdf_files", 
  glob= "**/*.pdf",  # Pattern to match files
  loader_cls = PyMuPDFLoader,
)
pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'jsPDF 2.3.1', 'creator': '', 'creationdate': '2026-07-05T21:27:30+05:30', 'source': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'file_path': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'total_pages': 4, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260705212730+05'30'", 'page': 0}, page_content=''),
#  Document(metadata={'producer': 'jsPDF 2.3.1', 'creator': '', 'creationdate': '2026-07-05T21:27:30+05:30', 'source': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'file_path': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'total_pages': 4, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260705212730+05'30'", 'page': 1}, page_content=''),
#  Document(metadata={'producer': 'jsPDF 2.3.1', 'creator': '', 'creationdate': '2026-07-05T21:27:30+05:30', 'source': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'file_path': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'total_pages': 4, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260705212730+05'30'", 'page': 2}, page_content=''),
#  Document(metadata={'producer': 'jsPDF 2.3.1', 'creator': '', 'creationdate': '2026-07-05T21:27:30+05:30', 'source': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'file_path': '..\\data\\pdf_files\\Online Application Receipt - passport.pdf', 'total_pages': 4, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': "D:20260705212730+05'30'", 'page': 3}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-08-15T12:24:27+00:00', 'source': '..\\data\\pdf_files\\ParasResume.pdf', 'file_path': '..\\data\\pdf_files\\ParasResume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-08-15T12:24:27+00:00', 'trapped': '', 'modDate': 'D:20250815122427Z', 'creationDate': 'D:20250815122427Z', 'page': 0}, page_content='Paras Upadhayay\n\x83 +91 8630853056\n# parasupadhayay95@gmail.com\nï linkedin.com/in/pudv95\n§ github.com/pudv95\nEducation\nAjay Kumar Garg Engineering College\nSeptember 2022 – May 2026\nBachelor of Technology in Computer Science\nGhaziabad, U.P.\nExperience\nClickPe (YC W23)\nJune 2025 – Present\nSoftware Developer Intern\nRemote\n• Published a production-grade app to the App Store, integrating Firebase Analytics and Crashlytics to track KPIs,\nachieving a 20% reduction in crash rates and improving user retention.\n• Developed and deployed backend APIs on AWS Lambda (Python), integrating with DynamoDB and S3, reducing backend\nresponse times by 35%.\n• Built a CI/CD pipeline that automated app builds, ran integration tests, and uploaded signed artifacts to AWS S3,\ncutting release preparation time by 40%.\n• Forked and customized a pub.dev package to meet unique business requirements, accelerating feature delivery by 30%.\n• Collaborated in sprint planning using Jira, utilized Metabase dashboards for data-driven decisions, and contributed to\nfeature architecture from ideation to deployment.\nInfitout Technologies\nAug 2024 – June 2025\nFlutter Developer Intern\nRemote\n• Developed and launched a trading app for Alice Blue, available on the App Store and Play Store, reaching 10,000+\ndownloads and delivering a smooth trading experience.\n• Delivered cross-app login by integrating with Alice Blue’s ANT MOBI using deep linking, making the authorization\nprocess faster and more user-friendly.\n• Engineered interactive and easy-to-read graphs, such as treemaps and candlestick charts, to display trading data clearly\nand boost user engagement by 30%.\n• Integrated CleverTap SDK to track user behavior, send targeted push notifications, and analyze feature usage, helping\nimprove retention and app performance.\nProjects\nTrackSheet | Flutter, Dart | PlayStore | AppStore\nJune 2025\n• Architected and published a Student Portal, reaching over 3.26K total installs and maintaining a consistent 4.15 star\naverage rating on the Google Play Store.\n• Achieved rapid user growth reaching 1300 daily active users and 5000 monthly active users.\n• Executed a CI/CD pipeline using GitHub Actions, Fastlane, and Shorebird, reducing development and release time by\nover 50% through automation.\n• Maintained technical quality with a low 0.281% crash rate and 0.069% ANR rate, ensuring a stable and responsive user\nexperience across 2.21K active devices.\nBytepad | Flutter, Dart | Play Store\nNovember 2023\n• Built a Flutter app allowing students to view and download 3000+ previous year papers categorized by subject and\nsemester.\n• Implemented an optimized in-app PDF viewer and caching system, reducing load time by 40% and enabling smooth\noffline access.\n• Reduced UI jank by over 60% during scroll and navigation through performance profiling and efficient asset rendering.\nTechnical Skills\nLanguages: Dart, C, C++, Python, JavaScript, Java\nDeveloper Tools: VS Code, Android Studio, Git, Github\nTechnologies/Frameworks/Libraries: Flutter, Node.js, React.Js\nAchievements\n• ICPC Kanpur regionalist in 2024.\n• Achieved Specialist rating on Codeforces with a rating of 1429 and earned a 4-star rating on CodeChef with an 1819\nrating, demonstrating strong competitive programming skills and consistent performance.\n• Solved over 600 questions on LeetCode with rating of Knight(Top 5% 1850+ rating)')]

# %%
type(pdf_documents[1])
# Out:
# langchain_core.documents.base.Document
